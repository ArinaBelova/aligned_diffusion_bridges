# %%
# %load_ext autoreload

# %autoreload 2

from reproducibility.reproducibility import *

# %% [markdown]
# # Toy examples

# %% [markdown]
# ## Moon dataset

# %% [markdown]
# ### Training

# %%
AlignExperiment.run("--dataset=moon  --h_dim=64  --n_layers=2  --n_epochs=20  --reg_weight=1.  --timestep_emb_dim=32  --in_dim=2 --out_dim=2  --diffusivity_schedule=fbb  --max_diffusivity=1.0 --H=.5 --K=0 --use_drift_in_doobs=True  --activation=silu").save("moon_silu")
# Out:
# config {'data_dir': 'moon', 'log_dir': '../reproducibility/moon/model', 'config': None, 'task': 'synthetic', 'wandb_entity': None, 'group_name': None, 'wandb_mode': 'online', 'job_type': 'dev-train', 'online': False, 'dataset': 'moon', 'n_samples': 10000, 'train_bs': 32, 'val_bs': 8, 'transform': None, 'split_fracs': [0.8, 0.1, 0.1], 'num_workers': 1, 'in_dim': 2, 'out_dim': 2, 'timestep_emb_dim': 32, 'h_dim': 64, 'n_layers': 2, 'activation': 'silu', 'dropout_p': 0.1, 'run_name': 'fdjwscioy', 'n_epochs': 20, 'use_grad_noise': False, 'drift_weight': 1.0, 'reg_weight': 1.0, 'reg_weight_T': 1.0, 'reg_weight_t': 1.0, 'diffusivity_schedule': 'fbb', 'max_diffusivity': 1.0, 'H': 0.5, 'K': 0, 'use_drift_in_doobs': True, 'optim_name': 'adamw', 'lr': 0.001, 'weight_decay': 0.001, 'grad_clip_value': 10.0, 'scheduler': 'plateau', 'scheduler_mode': 'min', 'scheduler_patience': 10, 'ema_decay_rate': 0.999, 'log_every': 1000, 'eval_every': 10000, 'inference_every': 0, 'inference_steps': 100, 'inference_metric': 'val_rmsd', 'inference_goal': 'min', 'early_stop_metric': 'val_loss', 'early_stop_goal': 'min'}
#
# Args: Namespace(data_dir='moon', log_dir='../reproducibility/moon/model', config=None, task='synthetic', wandb_entity=None, group_name=None, wandb_mode='online', job_type='dev-train', online=False, dataset='moon', n_samples=10000, train_bs=32, val_bs=8, transform=None, split_fracs=[0.8, 0.1, 0.1], num_workers=1, in_dim=2, out_dim=2, timestep_emb_dim=32, h_dim=64, n_layers=2, activation='silu', dropout_p=0.1, run_name='fdjwscioy', n_epochs=20, use_grad_noise=False, drift_weight=1.0, reg_weight=1.0, reg_weight_T=1.0, reg_weight_t=1.0, diffusivity_schedule='fbb', max_diffusivity=1.0, H=0.5, K=0, use_drift_in_doobs=True, optim_name='adamw', lr=0.001, weight_decay=0.001, grad_clip_value=10.0, scheduler='plateau', scheduler_mode='min', scheduler_patience=10, ema_decay_rate=0.999, log_every=1000, eval_every=10000, inference_every=0, inference_steps=100, inference_metric='val_rmsd', inference_goal='min', early_stop_metric='val_loss', early_stop_goal='min')
#
# Experiment Name: fdjwscioy
#
# init H in fbb 0.5
# init K fbb 0
# Num Train: 8000, Num Valid: 1000
# Train loader inspection: tensor([ 0.0091, -0.0074])
# Val loader inspection: tensor([ 0.0050, -0.0233])
#
# Model with 0.06074M parameters
#
# Saved model config to ../reproducibility/moon/model/fdjwscioy/config_train.yml
#
# Training model for 20 epochs...
# init H in fbb 0.5
# init K fbb 0
# init H in fbb 0.5
# init K fbb 0
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/data/datasets.py:180: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data_full = torch.load(filename, map_location=device)
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 1: Training Loss: 0.1009 bb_loss 0.0895 reg_loss_T 0.0036 reg_loss_t 0.0078
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 1: Validation Loss: 0.0497 bb_loss 0.0495 reg_loss_T 0.0 reg_loss_t 0.0001
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 2: Training Loss: 0.0643 bb_loss 0.0625 reg_loss_T 0.0004 reg_loss_t 0.0014
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 2: Validation Loss: 0.0532 bb_loss 0.0531 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 3: Training Loss: 0.0599 bb_loss 0.0589 reg_loss_T 0.0003 reg_loss_t 0.0008
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 3: Validation Loss: 0.0504 bb_loss 0.0504 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 4: Training Loss: 0.0561 bb_loss 0.0554 reg_loss_T 0.0002 reg_loss_t 0.0006
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 4: Validation Loss: 0.0489 bb_loss 0.0489 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 5: Training Loss: 0.054 bb_loss 0.0535 reg_loss_T 0.0001 reg_loss_t 0.0004
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 5: Validation Loss: 0.0462 bb_loss 0.0462 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 6: Training Loss: 0.0542 bb_loss 0.0538 reg_loss_T 0.0001 reg_loss_t 0.0003
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 6: Validation Loss: 0.0539 bb_loss 0.0539 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 7: Training Loss: 0.0558 bb_loss 0.0554 reg_loss_T 0.0001 reg_loss_t 0.0003
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 7: Validation Loss: 0.0489 bb_loss 0.0489 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 8: Training Loss: 0.0571 bb_loss 0.0569 reg_loss_T 0.0001 reg_loss_t 0.0002
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 8: Validation Loss: 0.0421 bb_loss 0.0421 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 9: Training Loss: 0.0536 bb_loss 0.0534 reg_loss_T 0.0 reg_loss_t 0.0002
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 9: Validation Loss: 0.0414 bb_loss 0.0414 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 10: Training Loss: 0.0529 bb_loss 0.0527 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 10: Validation Loss: 0.0493 bb_loss 0.0493 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 11: Training Loss: 0.0553 bb_loss 0.0552 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 11: Validation Loss: 0.0437 bb_loss 0.0437 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 12: Training Loss: 0.0525 bb_loss 0.0523 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 12: Validation Loss: 0.0494 bb_loss 0.0494 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 13: Training Loss: 0.0518 bb_loss 0.0517 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 13: Validation Loss: 0.0401 bb_loss 0.0401 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 14: Training Loss: 0.0499 bb_loss 0.0499 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 14: Validation Loss: 0.0508 bb_loss 0.0508 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 15: Training Loss: 0.0514 bb_loss 0.0513 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 15: Validation Loss: 0.0456 bb_loss 0.0456 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 16: Training Loss: 0.0476 bb_loss 0.0475 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 16: Validation Loss: 0.0473 bb_loss 0.0473 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 17: Training Loss: 0.0496 bb_loss 0.0495 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 17: Validation Loss: 0.0391 bb_loss 0.039 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 18: Training Loss: 0.0496 bb_loss 0.0495 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 18: Validation Loss: 0.0388 bb_loss 0.0388 reg_loss_T 0.0 reg_loss_t 0.0
#
# After best validation, saving model to ../reproducibility/moon/model/fdjwscioy/best_model.pt
# After best validation, saving ema to ../reproducibility/moon/model/fdjwscioy/best_ema_model.pt
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 19: Training Loss: 0.0495 bb_loss 0.0494 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 19: Validation Loss: 0.0403 bb_loss 0.0403 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 20: Training Loss: 0.0497 bb_loss 0.0497 reg_loss_T 0.0 reg_loss_t 0.0001
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# Epoch 20: Validation Loss: 0.0419 bb_loss 0.0419 reg_loss_T 0.0 reg_loss_t 0.0
#
# Saving last model to ../reproducibility/moon/model/fdjwscioy/last_model.pt
#
# Best Validation Loss 0.0388 on Epoch 17
# Best Inference Metric inf on Epoch 0
# init H in fbb 0.5
# init K fbb 0
# diffusivity <class 'sbalign.training.diffusivity.FractionalSchrödingerBridge'>

# %% [markdown]
# ### Inference

# %%
moon = AlignExperiment.load("moon_silu")
# Out:
# Args: {'data_dir': 'moon', 'log_dir': '../reproducibility/moon/model', 'config': None, 'task': 'synthetic', 'wandb_entity': None, 'group_name': None, 'wandb_mode': 'online', 'job_type': 'dev-train', 'online': False, 'dataset': 'moon', 'n_samples': 10000, 'train_bs': 32, 'val_bs': 8, 'transform': None, 'split_fracs': [0.8, 0.1, 0.1], 'num_workers': 1, 'in_dim': 2, 'out_dim': 2, 'timestep_emb_dim': 32, 'h_dim': 64, 'n_layers': 2, 'activation': 'silu', 'dropout_p': 0.1, 'run_name': 'fdjwscioy', 'n_epochs': 20, 'use_grad_noise': False, 'drift_weight': 1.0, 'reg_weight': 1.0, 'reg_weight_T': 1.0, 'reg_weight_t': 1.0, 'diffusivity_schedule': 'fbb', 'max_diffusivity': 1.0, 'H': 0.5, 'K': 0, 'use_drift_in_doobs': True, 'optim_name': 'adamw', 'lr': 0.001, 'weight_decay': 0.001, 'grad_clip_value': 10.0, 'scheduler': 'plateau', 'scheduler_mode': 'min', 'scheduler_patience': 10, 'ema_decay_rate': 0.999, 'log_every': 1000, 'eval_every': 10000, 'inference_every': 0, 'inference_steps': 100, 'inference_metric': 'val_rmsd', 'inference_goal': 'min', 'early_stop_metric': 'val_loss', 'early_stop_goal': 'min'}
# cpu
# init H in fbb 0.5
# init K fbb 0
# diffusivity <class 'sbalign.training.diffusivity.FractionalSchrödingerBridge'>
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/reproducibility/reproducibility.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(filename))

# %%
plot_marginals(moon.get_marginals())

# %%
# %load_ext autoreload

# %autoreload 2

plot_marginals(moon.get_marginals(), alpha=.2)

#print(.shape)
samples = moon.sample(samples_num=500, trials_num=7)
print('samples shape',samples.shape)
if len(samples.shape) == 3:
    plot_multiple_marginals(samples, skip_step=4) 
else:
    plot_multiple_marginals(samples[:,:,:,0], skip_step=4)     
export_fig("fig_sb_align_moon_traj")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/fe/nobis/Projects/bridge/aligned_diffusion_bridges/sbalign/training/diffusivity.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.ones_like(torch.tensor(t)) * self.g_max
# samples shape (101, 500, 2)

# %%
if len(samples.shape) == 4:
    plot_multiple_marginals(samples[:,:,:,1], skip_step=4)

# %%
plot_marginals(moon.get_marginals(), alpha=.2)


moon_sampled = moon.sample(samples_num=1000, trials_num=2)

if len(moon_sampled.shape) == 4:
    moon_sampled = moon_sampled[:,:,:,0]

print('moon_sampled',moon_sampled.shape)
plot_matchings(*moon_sampled[[0,-1]])
plot_multiple_marginals(moon_sampled[[0,1,-2,-1]], skip_step=1, alpha=.9)
# Out:
# moon_sampled (101, 1000, 2)

# %%
plt.axis("off")
plt.axis("equal")

moon_sampled = moon.sample(samples_num=1000, trials_num=7)

if len(moon_sampled.shape) == 4:
    moon_sampled = moon_sampled[:,:,:,0]

plot_matchings(*moon_sampled[[0,-1]])
plot_multiple_marginals(moon_sampled, skip_step=99, labels=[r"$t_0$", r"$t_1$"], alpha=1)
export_fig("fig_sb_align_moon_match")

# %%
moon_sampled = moon.sample(samples_num=500, trials_num=7)

if len(moon_sampled.shape) == 4:
    moon_sampled = moon_sampled[:,:,:,0]
    
plot_matchings(*moon_sampled[[0,-1]], color=palette[0], lw=1.)
plot_matchings(*moon.get_marginals().values(), color=palette[-1], lw=.6, alpha=.5)

# %% [markdown]
# ## T dataset

# %% [markdown]
# ### Training

# %%
# AlignExperiment.run("--dataset=diagonal_matching  --h_dim=32  --n_layers=3  --n_epochs=20  --reg_weight=1.  --timestep_emb_dim=32  --diffusivity_schedule=constant  --max_diffusivity=1.  --use_drift_in_doobs=True  --activation=selu").save("t_dataset")

# %% [markdown]
# ### Inference

# %%
t_dataset = AlignExperiment.load("t_dataset")
# Out:
# Args: {'data_dir': 'diagonal_matching', 'log_dir': 'diagonal_matching/model', 'config': None, 'wandb_id': None, 'wandb_entity': 'sb-paired', 'wandb_project': None, 'run_name': 'hcypfnvih', 'online': False, 'dataset': 'diagonal_matching', 'n_samples': 10000, 'train_bs': 32, 'val_bs': 8, 'transform': None, 'split_fracs': [0.8, 0.1, 0.1], 'num_workers': 1, 'in_dim': 2, 'out_dim': 2, 'timestep_emb_dim': 32, 'h_dim': 32, 'n_layers': 3, 'activation': 'selu', 'dropout_p': 0.1, 'n_epochs': 20, 'use_grad_noise': False, 'drift_weight': 1.0, 'reg_weight': 1.0, 'diffusivity_schedule': 'constant', 'max_diffusivity': 1.0, 'use_drift_in_doobs': True, 'optim_name': 'adam', 'lr': 0.001, 'weight_decay': 0.001, 'grad_clip_value': 1.0, 'scheduler': 'plateau', 'scheduler_mode': 'min', 'ema_decay_rate': 0.999, 'log_every': 1000, 'eval_every': 10000, 'inference_every': 0, 'inference_steps': 100, 'inference_metric': 'val_rmsd', 'inference_goal': 'min', 'early_stop_metric': 'val_loss', 'early_stop_goal': 'min'}
# cpu
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t_dataset = AlignExperiment.load("t_dataset")
#
# File ~/Projects/bridge/aligned_diffusion_bridges/reproducibility/reproducibility.py:120, in AlignExperiment.load(tag)
#     117 experiment_conf = load_config(tag)
#     118 model_filename = AlignExperiment.get_model_path(experiment_conf)
# --> 120 return AlignExperiment(experiment_conf, *load_model(model_filename, experiment_conf))
#
# File ~/Projects/bridge/aligned_diffusion_bridges/reproducibility/reproducibility.py:67, in load_model(filename, args)
#      64 print(DEVICE)
#      65 model.to(DEVICE)
# ---> 67 model.load_state_dict(torch.load(filename))
#      69 dif = get_diffusivity_schedule(args.diffusivity_schedule, args.max_diffusivity, H=args.H, K=args.K)
#      71 return model, dif
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:1097, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1095             except RuntimeError as e:
#    1096                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1097         return _load(
#    1098             opened_zipfile,
#    1099             map_location,
#    1100             pickle_module,
#    1101             overall_storage=overall_storage,
#    1102             **pickle_load_args,
#    1103         )
#    1104 if mmap:
#    1105     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:1525, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1522 # Needed for tensors where storage device and rebuild tensor device are
#    1523 # not connected (wrapper subclasses and tensors rebuilt using numpy)
#    1524 torch._utils._thread_local_state.map_location = map_location
# -> 1525 result = unpickler.load()
#    1526 del torch._utils._thread_local_state.map_location
#    1528 torch._utils._validate_loaded_sparse_tensors()
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:1492, in _load.<locals>.persistent_load(saved_id)
#    1490 else:
#    1491     nbytes = numel * torch._utils._element_size(dtype)
# -> 1492     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1494 return typed_storage
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:1466, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1461         storage.byteswap(dtype)
#    1463 # TODO: Once we decide to break serialization FC, we can
#    1464 # stop wrapping with TypedStorage
#    1465 typed_storage = torch.storage.TypedStorage(
# -> 1466     wrap_storage=restore_location(storage, location),
#    1467     dtype=dtype,
#    1468     _internal=True)
#    1470 if typed_storage._data_ptr() != 0:
#    1471     loaded_storages[key] = typed_storage
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:414, in default_restore_location(storage, location)
#     412 def default_restore_location(storage, location):
#     413     for _, _, fn in _package_registry:
# --> 414         result = fn(storage, location)
#     415         if result is not None:
#     416             return result
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:391, in _deserialize(backend_name, obj, location)
#     389     backend_name = torch._C._get_privateuse1_backend_name()
#     390 if location.startswith(backend_name):
# --> 391     device = _validate_device(location, backend_name)
#     392     return obj.to(device=device)
#
# File ~/anaconda3/envs/sbalign_test/lib/python3.9/site-packages/torch/serialization.py:364, in _validate_device(location, backend_name)
#     362     device_index = device.index if device.index else 0
#     363 if hasattr(device_module, 'is_available') and not device_module.is_available():
# --> 364     raise RuntimeError(f'Attempting to deserialize object on a {backend_name.upper()} '
#     365                        f'device but torch.{backend_name}.is_available() is False. '
#     366                        'If you are running on a CPU-only machine, '
#     367                        'please use torch.load with map_location=torch.device(\'cpu\') '
#     368                        'to map your storages to the CPU.')
#     369 if hasattr(device_module, 'device_count'):
#     370     device_count = device_module.device_count()
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
plt.axis('off');
plot_marginals(t_dataset.get_marginals())

# %%
plt.axis("off")
plt.axis("equal")
t_sampled = t_dataset.sample(samples_num=1000, trials_num=50)
plot_multiple_marginals(t_sampled, skip_step=99, labels=[r"$t_0$", r"$t_1$"], alpha=1)
plot_matchings(*t_sampled[[0,-1]])
export_fig("fig_sb_align_t_match")

# %%
plt.axis("off")
plt.axis("equal")
plot_marginals(t_dataset.get_marginals())
plot_multiple_marginals(t_dataset.sample(trials_num=50), skip_step=2)
export_fig("fig_sb_align_t_traj")

# %% [markdown]
# ## T dataset (inverse)

# %% [markdown]
# ### Training

# %%
# AlignExperiment.run("--dataset=diagonal_matching_inverse  --h_dim=32  --n_layers=3  --n_epochs=20  --reg_weight=1.  --timestep_emb_dim=32  --diffusivity_schedule=constant  --max_diffusivity=1.  --use_drift_in_doobs=True  --activation=selu").save("t_dataset_inverse")

# %% [markdown]
# ### Inference

# %%
t_dataset_inverse = AlignExperiment.load("t_dataset_inverse")
# Out:
# Args: {'data_dir': 'diagonal_matching_inverse', 'log_dir': 'diagonal_matching_inverse/model', 'config': None, 'wandb_id': None, 'wandb_entity': 'sb-paired', 'wandb_project': None, 'run_name': 'wntpmqdhj', 'online': False, 'dataset': 'diagonal_matching_inverse', 'n_samples': 10000, 'train_bs': 32, 'val_bs': 8, 'transform': None, 'split_fracs': [0.8, 0.1, 0.1], 'num_workers': 1, 'in_dim': 2, 'out_dim': 2, 'timestep_emb_dim': 32, 'h_dim': 32, 'n_layers': 3, 'activation': 'selu', 'dropout_p': 0.1, 'n_epochs': 20, 'use_grad_noise': False, 'drift_weight': 1.0, 'reg_weight': 1.0, 'diffusivity_schedule': 'constant', 'max_diffusivity': 1.0, 'use_drift_in_doobs': True, 'optim_name': 'adam', 'lr': 0.001, 'weight_decay': 0.001, 'grad_clip_value': 1.0, 'scheduler': 'plateau', 'scheduler_mode': 'min', 'ema_decay_rate': 0.999, 'log_every': 1000, 'eval_every': 10000, 'inference_every': 0, 'inference_steps': 100, 'inference_metric': 'val_rmsd', 'inference_goal': 'min', 'early_stop_metric': 'val_loss', 'early_stop_goal': 'min'}

# %%
plt.axis('off');
plot_marginals(t_dataset_inverse.get_marginals())
plot_multiple_marginals(t_dataset_inverse.sample(trials_num=50), skip_step=12)

# %%
common_marginals = t_dataset.get_marginals()

# %%
plt.axis('off');
plot_marginals(common_marginals)
plot_multiple_marginals(mix_trajs(t_dataset.sample(input_data=common_marginals['initial'].to(DEVICE), trials_num=50), sample_inverse(t_dataset_inverse, input_data=common_marginals['initial'].to(DEVICE), trials_num=20)), skip_step=12)
